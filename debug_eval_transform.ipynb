# %% [markdown]
# # Debug SimCLREvalDataTransform

# %%
from pl_bolts.models.self_supervised.simclr import SimCLREvalDataTransform

# %%
import pl_bolts
print(pl_bolts.__version__)
# Out:
# 0.5.0

# %%
from PIL import Image

# %%
pillow_image = Image.open('./dog.png').convert('RGB')
pillow_image.size
# Out:
# (525, 510)

# %%
pillow_image
# Out:
# <PIL.Image.Image image mode=RGB size=525x510 at 0x7F9DE2202FD0>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
transform = SimCLREvalDataTransform(input_height=32)
image_transformed = transform(pillow_image)

# %%
plt.imshow(np.moveaxis(np.array(image_transformed[0]), 0, -1))

# %%
plt.imshow(np.moveaxis(np.array(image_transformed[1]), 0, -1))

# %%
plt.imshow(np.moveaxis(np.array(image_transformed[2]), 0, -1))
